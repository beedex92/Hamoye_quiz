# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("desktop/energydata.csv")
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.loc[:, df.columns!='date']
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...         T9     RH_9  \
# ...

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
columns_names = {'T1':'temperature_in_kitchen_area', 'RH_1':'humidity_in_kitchen_area', 
                'T2':'temperature_in_living_room_area', 'RH_2':'humidity_in_living_room_area',
                'T3':'temperature_in_laundry_room_area', 'RH_3':'humidity_in_laundry_room_area',
                'T4':'temperature_in_office_room', 'RH_4':'humidity_in_office_room',
                'T5':'temperature_in_bathroom', 'RH_5':'humidity_in_bathroom',
                'T6':'temperature_outside_the_building_northside', 'RH_6':'humidity_outside_the_building_northside', 
                'T7':'temperature_in_ironing_room', 'RH_7':'humidity_in_ironing_room',
                'T8':'temperature_in_tenager_room_2', 'RH_8':'humidity_in_tenager_room_2',
                'T9':'temperature_in_parents_room', 'RH_9':'humidity_in_parents_room',
                'T_out':'temperature_outside', 
                'Press_mm_hg':'Pressure', 'RH_out':'humidity_outside', 'Windspeed':'windspeed',
                'Visibility':'visibility', 'Tdewpoint':'tdewpoint',
                'rv1':'random_variable_1', 'rv2':'random_variable_2'}

# %%
df = df.rename(columns = columns_names)

# %%
df.head()
# Out:
#                   date  Appliances  lights  temperature_in_kitchen_area  \
# 0  2016-01-11 17:00:00          60      30                        19.89
# 1  2016-01-11 17:10:00          60      30                        19.89
# 2  2016-01-11 17:20:00          50      30                        19.89
# 3  2016-01-11 17:30:00          50      40                        19.89
# 4  2016-01-11 17:40:00          60      40                        19.89
#
#    humidity_in_kitchen_area  temperature_in_living_room_area  \
# 0                 47.596667                             19.2
# 1                 46.693333                             19.2
# 2                 46.300000                             19.2
# 3                 46.066667                             19.2
# 4                 46.333333                             19.2
#
#    humidity_in_living_room_area  temperature_in_laundry_room_area  \
# 0                     44.790000                             19.79
# ...

# %%
df['date'] = df['date'].fillna(0)

# %%
df.head()
# Out:
#                   date  Appliances  lights  temperature_in_kitchen_area  \
# 0  2016-01-11 17:00:00          60      30                        19.89
# 1  2016-01-11 17:10:00          60      30                        19.89
# 2  2016-01-11 17:20:00          50      30                        19.89
# 3  2016-01-11 17:30:00          50      40                        19.89
# 4  2016-01-11 17:40:00          60      40                        19.89
#
#    humidity_in_kitchen_area  temperature_in_living_room_area  \
# 0                 47.596667                             19.2
# 1                 46.693333                             19.2
# 2                 46.300000                             19.2
# 3                 46.066667                             19.2
# 4                 46.333333                             19.2
#
#    humidity_in_living_room_area  temperature_in_laundry_room_area  \
# 0                     44.790000                             19.79
# ...

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
simple_linear_reg_df = df[['temperature_in_living_room_area', 'temperature_outside_the_building_northside']].sample(15, random_state = 2)

# %%
simple_linear_reg_df
# Out:
#        temperature_in_living_room_area  \
# 1117                         17.426667
# 16275                        22.760000
# 13272                        21.230000
# 3160                         21.100000
# 19210                        21.856667
# 8260                         17.356667
# 12299                        19.000000
# 13505                        22.700000
# 12913                        19.593333
# 17788                        21.890000
# 17894                        21.500000
# 7665                         19.142857
# 10165                        18.000000
# 18809                        22.400000
# 8737                         17.066667
#
#        temperature_outside_the_building_northside
# 1117                                    -4.238889
# 16275                                   14.690000
# 13272                                    8.926667
# 3160                                     7.690000
# 19210                                   10.800000
# ...

# %%
sns.regplot(x = "temperature_in_living_room_area", y = "temperature_outside_the_building_northside", data = simple_linear_reg_df)
# Out:
# <AxesSubplot:xlabel='temperature_in_living_room_area', ylabel='temperature_outside_the_building_northside'>

# %%
from sklearn.metrics import r2_score

# %%
#Firstly normalise dataset to a common scale using the min max scaler
from sklearn.preprocessing import MinMaxScaler

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
del df["date"]
del df["lights"]

# %%
df.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns = df.columns)
features_df = normalised_df.drop(columns = ['T2', 'T6'])
random_variable = normalised_df['T2']

# %%
#Now, we split our dataset into the training and testing dataset. Recall that we had earlier segmented the features and target variables.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features_df, random_variable, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
#fit the model to the training dataset
linear_model.fit(x_train, y_train)
#obtain predictions
predicted_values = linear_model.predict(x_test)

# %%
#MAE
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 3)
# Out:
# 0.022

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 3)
# Out:
# 0.96

# %%
import numpy as np
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 3)
# Out:
# 5.949

# %%
from sklearn.metrics import  mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.032

# %%
def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha = 0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha = 0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')

final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')
final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0           rv2        -6.562385e+10      0.000412      0.000000
# 1          RH_2        -1.096747e+00     -1.078217     -0.535951
# 2            T7        -7.999580e-02     -0.078343      0.000000
# 3          RH_8        -5.791795e-02     -0.057608      0.000000
# 4            T8        -4.238190e-02     -0.042862     -0.000000
# 5          RH_6        -2.743480e-02     -0.027537     -0.012658
# 6            T3        -2.606314e-02     -0.023838      0.000000
# 7     Windspeed        -2.062479e-02     -0.021064     -0.000000
# 8    Appliances        -1.959721e-02     -0.017783      0.000000
# 9   Press_mm_hg        -7.584097e-03     -0.008200     -0.000000
# 10           T5        -1.706583e-03     -0.001167      0.000000
# 11   Visibility         3.649878e-03      0.003825      0.000000
# 12       RH_out         6.773417e-03      0.003759     -0.021085
# ...

# %%
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.032
